# %% [markdown]
# <a href="https://colab.research.google.com/github/tawfiqml/Machine-Learning-AI-work-flow/blob/main/Problem_no_1_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Problem no-1
# Please solve the below Tasks by implementing in python for the given dataset
#
# Data Set: https://www.kaggle.com/datasets/dansbecker/cityscapes-image-pairs
# Task 1: Enhance image quality to deal with varying lighting conditions.
# Task 2:Detect edges of vehicles and road markings to assess traffic patterns.
# Task 3: Apply filters to reduce noise and improve the clarity of moving objects
#
# Instruction: You can use chatgpt for help. But dont copy and paste
# Submission: Upload your all codes/documents in your github repository and Submit.
# Submission Deadline: 13th November, 2024, 11:59 PM. We will not accept any submission after this.

# %% [markdown]
# Task 1: Enhance image quality to deal with varying lighting conditions.

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Load the image
image_path = '/content/drive/MyDrive/130.jpg'
image = cv2.imread(image_path)

# Convert to grayscale
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# Apply Gaussian Blur to reduce noise
blurred = cv2.GaussianBlur(gray, (5, 5), 0)

# Apply Canny Edge Detector
edges = cv2.Canny(blurred, threshold1=50, threshold2=150)

# Optionally, overlay edges on the original image
edges_overlay = cv2.addWeighted(image, 0.8, cv2.cvtColor(edges, cv2.COLOR_GRAY2BGR), 0.2, 0)

# Save the results
cv2.imwrite('/mnt/data/edges.jpg', edges)
cv2.imwrite('/mnt/data/edges_overlay.jpg', edges_overlay)

# Display the results
plt.figure(figsize=(18, 6))

plt.subplot(1, 3, 1)
plt.title('Original Image')
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.axis('off')

plt.subplot(1, 3, 2)
plt.title('Detected Edges')
plt.imshow(edges, cmap='gray')
plt.axis('off')

plt.subplot(1, 3, 3)
plt.title('Edges Overlay')
plt.imshow(cv2.cvtColor(edges_overlay, cv2.COLOR_BGR2RGB))
plt.axis('off')

plt.show()

# %% [markdown]
# Task 2: Detect edges of vehicles and road markings to assess traffic patterns.

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Load the image
image_path = '/content/drive/MyDrive/130.jpg'
image = cv2.imread(image_path)

# Step 1: Convert to grayscale
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# Step 2: Apply Gaussian blur to reduce noise
blurred = cv2.GaussianBlur(gray, (5, 5), 0)

# Step 3: Apply Canny edge detection
edges = cv2.Canny(blurred, threshold1=50, threshold2=150)

# Save the result
cv2.imwrite('/content/drive/MyDrive/traffic_edges.jpg', edges)

# Display the results
plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
plt.title('Original Image')
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.axis('off')

plt.subplot(1, 2, 2)
plt.title('Detected Edges (Vehicles and Road Markings)')
plt.imshow(edges, cmap='gray')
plt.axis('off')

plt.show()

# %% [markdown]
# Task 3: Apply filters to reduce noise and improve the clarity of moving objects

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Load the image
image_path = '/content/drive/MyDrive/130.jpg'
image = cv2.imread(image_path)

# Step 1: Apply Bilateral Filtering for noise reduction while preserving edges
denoised_image = cv2.bilateralFilter(image, d=9, sigmaColor=75, sigmaSpace=75)

# Step 2: Sharpen the image using an unsharp mask
# Create a blurred version of the denoised image
blurred = cv2.GaussianBlur(denoised_image, (5, 5), 0)

# Enhance sharpness by subtracting blurred from original
sharpened = cv2.addWeighted(denoised_image, 1.5, blurred, -0.5, 0)

# Save results
cv2.imwrite('/content/drive/MyDrive/denoised_image.jpg', denoised_image)
cv2.imwrite('/content/drive/MyDrive/sharpened_image.jpg', sharpened)

# Display results
plt.figure(figsize=(18, 6))

plt.subplot(1, 3, 1)
plt.title('Original Image')
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.axis('off')

plt.subplot(1, 3, 2)
plt.title('Denoised Image')
plt.imshow(cv2.cvtColor(denoised_image, cv2.COLOR_BGR2RGB))
plt.axis('off')

plt.subplot(1, 3, 3)
plt.title('Sharpened Image')
plt.imshow(cv2.cvtColor(sharpened, cv2.COLOR_BGR2RGB))
plt.axis('off')

plt.show()
